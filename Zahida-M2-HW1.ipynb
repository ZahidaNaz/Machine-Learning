# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

os.chdir("C:/Users/FARIYA/Desktop")
dataset = pd.read_csv('Cricket.csv')
display(dataset)
# Out:
#    ConsecutiveWins  Season Opposition_Others       Country        Ground  \
# 0                0  Summer       New Zealand   New Zealand    Wellington
# 1                0  Summer       New Zealand  South Africa    Queenstown
# 2                0  Summer       New Zealand   New Zealand  Christchurch
# 3                1  Summer       New Zealand   New Zealand        Napier
# 4                2  Summer       New Zealand   New Zealand      Hamilton
# ..             ...     ...               ...           ...           ...
# 90               1  Summer         Sri Lanka      SriLanka    Hambantota
# 91               0  Summer         Sri Lanka      SriLanka      Dambulla
# 92               0  Spring         Australia           UAE       Sharjah
# 93               0  Spring         Australia           UAE   Dubai (DSC)
# 94               0  Spring         Australia           UAE     Abu Dhabi
#
#    Home_Ground Day_Night PitchReport BattingFirst Combination Changed  Pak_Win
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ConsecutiveWins       95 non-null     object
#  1   Season                94 non-null     object
#  2   Opposition_Others     94 non-null     object
#  3   Country               95 non-null     object
#  4   Ground                95 non-null     object
#  5   Home_Ground           94 non-null     object
#  6   Day_Night             95 non-null     object
#  7   PitchReport           95 non-null     object
#  8   BattingFirst          94 non-null     object
#  9   Combination Changed   12 non-null     object
#  10  Pak_Win               94 non-null     object
# dtypes: object(11)
# memory usage: 8.3+ KB

# %%
dataset.isnull().sum()
# Out:
# ConsecutiveWins          0
# Season                   1
# Opposition_Others        1
# Country                  0
# Ground                   0
# Home_Ground              1
# Day_Night                0
# PitchReport              0
# BattingFirst             1
# Combination Changed     83
# Pak_Win                  1
# dtype: int64

# %%
missing=["A","B","Others","ABC",45]
dataset=pd.read_csv('Cricket.csv',na_values=missing)

# %%
median=dataset['ConsecutiveWins'].median()
dataset['ConsecutiveWins'].fillna(median,inplace=True)

# %%
dataset['Opposition_Others'].mode()
dataset['Opposition_Others'].fillna(dataset['Opposition_Others'].mode()[0],inplace=True)

# %%
dataset['Country'].mode()
dataset['Country'].fillna(dataset['Country'].mode()[0],inplace=True)

# %%
dataset['Home_Ground'].mode()
dataset['Home_Ground'].fillna(dataset['Home_Ground'].mode()[0],inplace=True)

# %%
dataset['BattingFirst'].mode()
dataset['BattingFirst'].fillna(dataset['BattingFirst'].mode()[0],inplace=True)

# %%
dataset['Pak_Win'].mode()
dataset['Pak_Win'].fillna(dataset['Pak_Win'].mode()[0],inplace=True)

# %%
dataset.rename(columns={ dataset.columns[9]: "Combination_Changed" },inplace=True)

# %%
dataset['Combination_Changed'].mode()
dataset['Combination_Changed'].fillna(dataset['Combination_Changed'].mode()[0],inplace=True)

# %%
dataset.head(50)
# Out:
#     ConsecutiveWins  Season Opposition_Others       Country         Ground  \
# 0               0.0  Summer       New Zealand   New Zealand     Wellington
# 1               0.0  Summer       New Zealand  South Africa     Queenstown
# 2               0.0  Summer       New Zealand   New Zealand   Christchurch
# 3               1.0  Summer       New Zealand   New Zealand         Napier
# 4               2.0  Summer       New Zealand   New Zealand       Hamilton
# 5               3.0  Summer       New Zealand   New Zealand       Auckland
# 6               0.0  Winter         Sri Lanka      SriLanka     Hambantota
# 7               1.0  Winter         Sri Lanka      SriLanka  Colombo (RPS)
# 8               2.0  Spring         Sri Lanka      SriLanka  Colombo (RPS)
# 9               3.0  Autumn       New Zealand      SriLanka      Pallekele
# 10              1.0  Autumn          Zimbabwe      SriLanka      Pallekele
# ...

# %%
dataset['Country'].value_counts().plot(kind='bar',figsize=(10,6),color='pink')

# %%
dataset['Pak_Win'].value_counts().plot(kind='bar',figsize=(10,6),color='orange')

# %%
dataset['ConsecutiveWins'].plot.hist(bins=10)

# %%
sns.boxplot(x='ConsecutiveWins',data=dataset,color='green')

# %%
dataset['BattingFirst'].value_counts().plot(kind='bar',figsize=(10,6),color='purple')
